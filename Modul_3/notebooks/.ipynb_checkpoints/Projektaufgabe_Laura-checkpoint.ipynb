# %%
#Ist leider noch in Arbeit, da ich es noch nicht geschafft habe alle so umzusetzten wie ich wollte
#Siehe Fragen an Zellen

import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
df = pd.read_csv("../data/Library_Usage.csv")
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
(df['Patron Type Definition'] == 'SENIOR').sum()
# Out:
# 41619

# %%
(df['Patron Type Definition'] == 'JUVENILE').sum()
# Out:
# 59208

# %%
row_filter = (df['Patron Type Definition'] == 'SENIOR') | (df['Patron Type Definition'] == 'JUVENILE')
df.loc[row_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 5                      3                 SENIOR                0
# 34                     3                 SENIOR               29
# 62                     3                 SENIOR              193
# 159                    3                 SENIOR                0
# 176                    3                 SENIOR                7
# ...                  ...                    ...              ...
# 423434                 1               JUVENILE               10
# 423437                 1               JUVENILE                0
# 423439                 1               JUVENILE                0
# 423441                 3                 SENIOR             1812
# 423447                 1               JUVENILE                0
#
#         Total Renewals          Age Range Home Library Code  \
# 5                    0     65 to 74 years                C2
# 34                   0     65 to 74 years                O7
# ...

# %%
sns.set(font_scale=1.4)

df['Patron Type Definition'].value_counts ().plot(kind='bar')
# Wie nur Senior and Juvenile ?
# Out:
# <AxesSubplot:>

# %%
sns.set(font_scale=1.4)

df['Patron Type Definition'].value_counts ().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Wie viele nutzer möchten per E-Mail infomiert werden
(df['Notice Preference Definition']== 'email').value_counts()
# Out:
# True     323937
# False     99511
# Name: Notice Preference Definition, dtype: int64

# %%
sns.set(font_scale=1.4)

df['Notice Preference Definition'].value_counts ().plot(kind='bar')

#Wie verbinden mit Spalte Provided Email Address
# Out:
# <AxesSubplot:>
