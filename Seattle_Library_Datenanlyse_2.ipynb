# %%
import urllib.request
import pandas as pd

# %%
# Checkout-Daten über die API beziehen und als CSV-Datei speichern
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2019&$limit=10000"
checkout_file2019 = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file2019)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7feb675f3f10>)

# %%
#In einen DataFrame laden und analysieren
checkouts_df_2019 = pd.read_csv(checkout_file2019)

# %%
checkouts_df_2019
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2019              1
# 1       Digital    OverDrive        EBOOK          2019              2
# 2       Digital    OverDrive        EBOOK          2019              2
# 3       Digital    OverDrive        EBOOK          2019              3
# 4      Physical      Horizon    VIDEODISC          2019              3
# ...         ...          ...          ...           ...            ...
# 9995    Digital    OverDrive    AUDIOBOOK          2019              1
# 9996   Physical      Horizon         BOOK          2019              1
# 9997   Physical      Horizon         BOOK          2019              1
# 9998    Digital    OverDrive    AUDIOBOOK          2019              1
# 9999   Physical      Horizon    VIDEODISC          2019              1
#
#       checkouts                                              title  \
# ...

# %%
# Checkout-Daten über die API beziehen und als CSV-Datei speichern
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2020&$limit=10000"
checkout_file2020 = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file2020)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7feb672b5370>)

# %%
checkouts_df_2020 = pd.read_csv(checkout_file2020)

# %%
checkouts_df_2020
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2020              8
# 1       Digital    OverDrive        EBOOK          2020              8
# 2       Digital    OverDrive        EBOOK          2020              8
# 3       Digital    OverDrive        EBOOK          2020              8
# 4       Digital    OverDrive        EBOOK          2020              8
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon         BOOK          2020              1
# 9996   Physical      Horizon         BOOK          2020              1
# 9997   Physical      Horizon         BOOK          2020              1
# 9998    Digital    OverDrive    AUDIOBOOK          2020              1
# 9999    Digital    OverDrive        EBOOK          2020              1
#
#       checkouts                                              title  \
# ...

# %%
checkouts_df["materialtype"].value_counts()
# Out:
# BOOK                    4743
# EBOOK                   2480
# AUDIOBOOK               1038
# SOUNDDISC                838
# VIDEODISC                833
# MUSIC                     21
# REGPRINT                  12
# SOUNDDISC, VIDEODISC       8
# MAGAZINE                   6
# VIDEO                      5
# SOUNDREC                   4
# CR                         4
# ER                         4
# ER, SOUNDDISC              2
# ATLAS                      1
# VISUAL                     1
# Name: materialtype, dtype: int64

# %%
# Checkout-Daten über die API beziehen und als CSV-Datei speichern
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2021&$limit=10000"
checkout_file2021 = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file2021)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7feb672b5070>)
